# %% [markdown]
# # Introduction to generative adversarial networks

# %%
# GAN generator network
import keras
from keras import layers
import numpy as np

latent_dim = 32
height = 32
width = 32
channels = 3

generator_input = keras.Input(shape=(latent_dim,))

x = layers.Dense(128*16*16)(generator_input)
x = layers.LeakyReLU()(x)
x = layers.Reshape((16, 16, 128))(x)

x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32)]              0
# _________________________________________________________________
# dense (Dense)                (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 32768)             0
# _________________________________________________________________
# reshape (Reshape)            (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %%
# The GAN discriminator network
discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

x = layers.Dropout(0.4)(x)
x = layers.Dense(1, activation='sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()

discriminator_optimizer = keras.optimizers.RMSprop(
    lr=0.0008,
    clipvalue=1.0,
    decay=1e-8)

discriminator.compile(optimizer=discriminator_optimizer,
                      loss='binary_crossentropy')
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Adversarial network
discriminator.trainable = False

gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = keras.optimizers.RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %%
# Implementing GAN training
import os
from keras.preprocessing import image

(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()
# Selects frog images
x_train = x_train[y_train.flatten() == 6]

x_train = x_train.reshape((x_train.shape[0],)+(height, width, channels)).astype('float32') / 255.

iterations = 10000
batch_size = 20
save_dir = 'GAN_images'

start = 0
for step in range(iterations):
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))
    generated_images = generator.predict(random_latent_vectors)
    stop = start + batch_size
    real_images = x_train[start:stop]
    combined_images = np.concatenate([generated_images, real_images])
    labels = np.concatenate([np.ones((batch_size, 1)), np.zeros((batch_size, 1))])
    labels += 0.05 * np.random.random(labels.shape)

    d_loss = discriminator.train_on_batch(combined_images, labels)
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    misleading_targets = np.zeros((batch_size, 1))
    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
    
    start += batch_size
    if start > len(x_train) - batch_size:
        start = 0
    
    if step % 100 == 0:
        gan.save_weights('gan.h5')

        print('discriminator loss at step %s: %s' % (step, d_loss))
        print('adversarial loss at step %s: %s' % (step, a_loss))

        img = image.array_to_img(generated_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))

        img = image.array_to_img(real_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# discriminator loss at step 0: 7.107273101806641
# adversarial loss at step 0: 15.885098457336426
# discriminator loss at step 100: 0.69598388671875
# adversarial loss at step 100: 1.066025972366333
# discriminator loss at step 200: 0.6952202916145325
# adversarial loss at step 200: 0.7990283966064453
# discriminator loss at step 300: 0.6979197263717651
# adversarial loss at step 300: 0.7700600028038025
# discriminator loss at step 400: 0.6898626685142517
# adversarial loss at step 400: 0.8093053698539734
# discriminator loss at step 500: 0.7120109796524048
# adversarial loss at step 500: 0.7338616847991943
# discriminator loss at step 600: 0.6906957030296326
# adversarial loss at step 600: 0.7341623306274414
# discriminator loss at step 700: 0.764607310295105
# adversarial loss at step 700: 0.7805976271629333
# discriminator loss at step 800: 0.687387228012085
# adversarial loss at step 800: 0.7401645183563232
# discriminator loss at step 900: 0.6989858150482178
# adversarial loss at step 900: 0.710797131061554
# discriminator loss at step 1000: 0.6923864483833313
# adversarial loss at step 1000: 0.7446152567863464
# discriminator loss at step 1100: 0.6935082077980042
# adversarial loss at step 1100: 1.1135361194610596
# discriminator loss at step 1200: 0.7002946138381958
# adversarial loss at step 1200: 0.7521194219589233
# discriminator loss at step 1300: 0.7078333497047424
# adversarial loss at step 1300: 0.7271437644958496
# discriminator loss at step 1400: 0.7138595581054688
# adversarial loss at step 1400: 0.7661288380622864
# discriminator loss at step 1500: 0.6811809539794922
# adversarial loss at step 1500: 0.7605689764022827
# discriminator loss at step 1600: 0.698647141456604
# adversarial loss at step 1600: 0.7511271834373474
# discriminator loss at step 1700: 0.6950924396514893
# adversarial loss at step 1700: 0.7573686838150024
# discriminator loss at step 1800: 0.6987212300300598
# adversarial loss at step 1800: 0.7518707513809204
# discriminator loss at step 1900: 0.6865512728691101
# adversarial loss at step 1900: 0.7508670091629028
# discriminator loss at step 2000: 0.6863141655921936
# adversarial loss at step 2000: 0.7534876465797424
# discriminator loss at step 2100: 0.7145199179649353
# adversarial loss at step 2100: 0.739851176738739
# discriminator loss at step 2200: 0.6972634792327881
# adversarial loss at step 2200: 0.7584419250488281
# discriminator loss at step 2300: 0.7371805906295776
# adversarial loss at step 2300: 0.7510288953781128
# discriminator loss at step 2400: 0.6757014989852905
# adversarial loss at step 2400: 0.704447865486145
# discriminator loss at step 2500: 0.6950978636741638
# adversarial loss at step 2500: 0.7610566020011902
# discriminator loss at step 2600: 0.6837968230247498
# adversarial loss at step 2600: 0.7498645186424255
# discriminator loss at step 2700: 0.6802998781204224
# adversarial loss at step 2700: 0.7190095782279968
# discriminator loss at step 2800: 0.7085245847702026
# adversarial loss at step 2800: 0.7310531139373779
# discriminator loss at step 2900: 0.6827378273010254
# adversarial loss at step 2900: 0.7797424793243408
# discriminator loss at step 3000: 0.6910623908042908
# adversarial loss at step 3000: 0.7182053327560425
# discriminator loss at step 3100: 0.6895641684532166
# adversarial loss at step 3100: 0.7675491571426392
# discriminator loss at step 3200: 0.7130400538444519
# adversarial loss at step 3200: 0.7319257855415344
# discriminator loss at step 3300: 0.6875354051589966
# adversarial loss at step 3300: 0.7469530701637268
# discriminator loss at step 3400: 0.6950473785400391
# adversarial loss at step 3400: 0.7519909143447876
# discriminator loss at step 3500: 0.6874169111251831
# adversarial loss at step 3500: 0.7786458134651184
# discriminator loss at step 3600: 0.7010432481765747
# adversarial loss at step 3600: 0.7934542894363403
# discriminator loss at step 3700: 0.7040594816207886
# adversarial loss at step 3700: 0.7811394333839417
# discriminator loss at step 3800: 0.6939823627471924
# adversarial loss at step 3800: 0.762682318687439
# discriminator loss at step 3900: 0.6771819591522217
# adversarial loss at step 3900: 0.6161491274833679
# discriminator loss at step 4000: 0.6854557991027832
# adversarial loss at step 4000: 0.748729944229126
# discriminator loss at step 4100: 0.7052193880081177
# adversarial loss at step 4100: 0.7859828472137451
# discriminator loss at step 4200: 0.6978638768196106
# adversarial loss at step 4200: 0.7472848892211914
# discriminator loss at step 4300: 0.6887708306312561
# adversarial loss at step 4300: 0.8004711270332336
# discriminator loss at step 4400: 0.6507061123847961
# adversarial loss at step 4400: 0.779208779335022
# discriminator loss at step 4500: 0.6642605066299438
# adversarial loss at step 4500: 0.7435427904129028
# discriminator loss at step 4600: 0.756324052810669
# adversarial loss at step 4600: 0.8961082696914673
# discriminator loss at step 4700: 0.7753345966339111
# adversarial loss at step 4700: 0.8220065236091614
# discriminator loss at step 4800: 0.7115803956985474
# adversarial loss at step 4800: 0.7613716125488281
# discriminator loss at step 4900: 0.682452380657196
# adversarial loss at step 4900: 0.7772815227508545
# discriminator loss at step 5000: 0.6882454752922058
# adversarial loss at step 5000: 0.7607990503311157
# discriminator loss at step 5100: 0.6658722758293152
# adversarial loss at step 5100: 0.8554054498672485
# discriminator loss at step 5200: 0.7117655277252197
# adversarial loss at step 5200: 0.7661939859390259
# discriminator loss at step 5300: 0.6849472522735596
# adversarial loss at step 5300: 0.7440718412399292
# discriminator loss at step 5400: 0.7026556730270386
# adversarial loss at step 5400: 0.8109291195869446
# discriminator loss at step 5500: 0.6723123788833618
# adversarial loss at step 5500: 0.7589368224143982
# discriminator loss at step 5600: 0.6795258522033691
# adversarial loss at step 5600: 0.8277922868728638
# discriminator loss at step 5700: 0.6734714508056641
# adversarial loss at step 5700: 0.751498818397522
# discriminator loss at step 5800: 1.1728919744491577
# adversarial loss at step 5800: 2.823742389678955
# discriminator loss at step 5900: 0.6814965009689331
# adversarial loss at step 5900: 0.7341209650039673
# discriminator loss at step 6000: 0.6956875920295715
# adversarial loss at step 6000: 0.8357537984848022
# discriminator loss at step 6100: 0.7417711615562439
# adversarial loss at step 6100: 0.9496822357177734
# discriminator loss at step 6200: 0.6938847899436951
# adversarial loss at step 6200: 0.8029578328132629
# discriminator loss at step 6300: 0.6802156567573547
# adversarial loss at step 6300: 0.8017106056213379
# discriminator loss at step 6400: 0.6860770583152771
# adversarial loss at step 6400: 0.7927294969558716
# discriminator loss at step 6500: 0.6656442880630493
# adversarial loss at step 6500: 0.961063027381897
# discriminator loss at step 6600: 0.6958416700363159
# adversarial loss at step 6600: 0.7303048968315125
# discriminator loss at step 6700: 0.7115112543106079
# adversarial loss at step 6700: 0.9410451650619507
# discriminator loss at step 6800: 0.6666049957275391
# adversarial loss at step 6800: 0.8622943758964539
# discriminator loss at step 6900: 0.6894904375076294
# adversarial loss at step 6900: 0.8110553622245789
# discriminator loss at step 7000: 0.6779805421829224
# adversarial loss at step 7000: 0.7381285429000854
# discriminator loss at step 7100: 0.6451401114463806
# adversarial loss at step 7100: 0.7843772172927856
# discriminator loss at step 7200: 0.6654637455940247
# adversarial loss at step 7200: 0.8559995889663696
# discriminator loss at step 7300: 0.6990543603897095
# adversarial loss at step 7300: 0.8206719160079956
# discriminator loss at step 7400: 0.6877360343933105
# adversarial loss at step 7400: 0.8083904385566711
# discriminator loss at step 7500: 0.7290002703666687
# adversarial loss at step 7500: 1.1370623111724854
# discriminator loss at step 7600: 0.7486459016799927
# adversarial loss at step 7600: 1.0288161039352417
# discriminator loss at step 7700: 0.6795669794082642
# adversarial loss at step 7700: 0.8553338050842285
# discriminator loss at step 7800: 0.6380242705345154
# adversarial loss at step 7800: 0.9023475646972656
# discriminator loss at step 7900: 0.6775745153427124
# adversarial loss at step 7900: 0.7761428952217102
# discriminator loss at step 8000: 0.6617159843444824
# adversarial loss at step 8000: 0.8003994822502136
# discriminator loss at step 8100: 0.8093765377998352
# adversarial loss at step 8100: 0.7064782381057739
# discriminator loss at step 8200: 0.6967453956604004
# adversarial loss at step 8200: 0.7736040353775024
# discriminator loss at step 8300: 0.6811848878860474
# adversarial loss at step 8300: 0.7595914006233215
# discriminator loss at step 8400: 0.9026557207107544
# adversarial loss at step 8400: 1.2146832942962646
# discriminator loss at step 8500: 0.6708836555480957
# adversarial loss at step 8500: 0.766045331954956
# discriminator loss at step 8600: 0.7278915643692017
# adversarial loss at step 8600: 0.762785792350769
# discriminator loss at step 8700: 0.7039310932159424
# adversarial loss at step 8700: 0.7768909931182861
# discriminator loss at step 8800: 0.7739406228065491
# adversarial loss at step 8800: 0.7953880429267883
# discriminator loss at step 8900: 0.6780462265014648
# adversarial loss at step 8900: 0.7401784062385559
# discriminator loss at step 9000: 0.7414058446884155
# adversarial loss at step 9000: 0.8493303060531616
# discriminator loss at step 9100: 1.369852900505066
# adversarial loss at step 9100: 0.9957700967788696
# discriminator loss at step 9200: 0.7125840783119202
# adversarial loss at step 9200: 0.7042659521102905
# discriminator loss at step 9300: 0.6877835988998413
# adversarial loss at step 9300: 0.7999894618988037
# discriminator loss at step 9400: 0.7115404605865479
# adversarial loss at step 9400: 0.6951562762260437
# discriminator loss at step 9500: 0.6619241237640381
# adversarial loss at step 9500: 0.7705044746398926
# discriminator loss at step 9600: 0.6695860028266907
# adversarial loss at step 9600: 0.7949697375297546
# discriminator loss at step 9700: 0.6952611804008484
# adversarial loss at step 9700: 0.8474264144897461
# discriminator loss at step 9800: 0.706908106803894
# adversarial loss at step 9800: 0.8153787851333618
# discriminator loss at step 9900: 0.7605939507484436
# adversarial loss at step 9900: 0.7239915132522583

# %%
import matplotlib.pyplot as plt

# Sample random points in the latent space
random_latent_vectors = np.random.normal(size=(10, latent_dim))

# Decode them to fake images
generated_images = generator.predict(random_latent_vectors)

for i in range(generated_images.shape[0]):
    img = image.array_to_img(generated_images[i] * 255., scale=False)
    plt.figure()
    plt.imshow(img)
    
plt.show()
